# %% [markdown]
# ____
# # Foundations of Data Science: Homework 1
#
# Welcome to your first homework assignment! This assignment will help you set up the necessary tools and familiarize yourself with course materials essential for your success in this Data Science course.
#
# ## Objectives
# By completing this homework, you will:
#
# * Familiarize yourself with course expectations and policies
# * Set up essential tools for the course
# * Assess your current Python knowledge
# * Begin engaging with course content

# %% [markdown]
# ____
# ## Tasks
#
# ### Read Course Materials (10 points)
#
# There are three important documents for this course. In this problem you will find them, read them and summarize them.
#  * Read the course syllabus (available in Teams and D2L as a PDF)
#     * In a new markdown cell, summarize the portions of the syllabus regarding attendance and late assignments.
#  * Read the AI policy (PDF)
#     * In a new markdown cell, summarize what you need to do to do when you use AI for an assignment.
#  * Read the AI guide to best practices (PDF)
#     * Also in a new markdown cell, give us some feedback on your experiences using AI in the past. How well did it work? What strategies have you developed for yourself, if any?
#
# ### GitHub Setup (10 points)
#
# You will use GitHub for your two projects. In addition to learning an important data science tool, this will allow you to retain all of your work beyond this course and share with people around the world.
#  * Create a GitHub account (if you don't already have one)
#  * If you are not already familiar with GH:
#     * [this](https://www.youtube.com/watch?v=tRZGeaHPoaw) is a great video - watch it slowly over the next week or so
#     * and, you can complete the GitHub Hello World guide: https://guides.github.com/activities/hello-world/
#  * Create a new repository for this course.
#
#  If you have any questions or problems with GH, please let us know!
#
# ### Initial and Python Surveys (10 points)
#
#  Complete the [initial survey](https://docs.google.com/forms/d/e/1FAIpQLSc86xvGnOgLzNUKC_wBhcXuhyRYqYLX7Vqhlw0I3Rga_5zSlw/viewform?usp=sf_link) _if you haven't already_.
#
#  Complete the Python coding knowledge survey: [click here](https://docs.google.com/forms/d/e/1FAIpQLSfiNjPuIISJH7RznayiZqwItHbgYGXZkruAbHQZnBeAODgg7A/viewform?usp=sf_link)
#
# Put a statement in a markdown cell that you have completed both of these.
#
# ### Textbook Reading (10 points)
#
#  Read Chapter 1 of "_Thinking Clearly with Data_"
#  * In a markdown cell, give a very high-level overview of the book
#    * what are its goals and how are those goals organized?
#    * what can you hope to get out of this book?
#  * Write a brief summary (200-300 words) of the key points from Chapter 1

# %% [markdown]
# ____
# ## Streamlit Setup and Test (10 points)
#
#  We will develop web apps using [Streamlit](https://streamlit.io) throughout the semester and your projects will use this tool.
#
# Install Streamlit on your computer, follow the installation guide: https://docs.streamlit.io/library/get-started/installation
#
# Note that Streamlit is run from the command line. [Read this.](https://docs.streamlit.io/get-started/fundamentals/main-concepts) Bookmark this documentation for later in the semester.
#
# Let us know if you have any issues with this.
#
# Next, create .py files with the following two codes and ensure that these run on your computer. It is not necessary that you understand what they do; the goal here is:
# 1. to get Streamlit operational on your computer, and let us know where the problems are,
# 2. and, see what Streamlit does and how it functions.
#
# Include screen shots to show that you got this to work.

# %%
# Streamlit Code 1

import streamlit as st

st.write("Hello World")

# %%
# Streamlit Code 2

import streamlit as st
import pandas as pd
import numpy as np

chart_data = pd.DataFrame(
   np.random.randn(20, 3),
   columns=['a', 'b', 'c'])

st.line_chart(chart_data)
# Out:
# DeltaGenerator()

# %% [markdown]
# ____
# ## Submission
#
# Submit this notebook to D2L. Do not submit anything else (e.g., a PDF)!
#
# ____
# ## Due Date
#
# This assignment is due Sunday, September 1 at midnight.

# %% [markdown]
# Course syllabus
# Topics covered:
# 1.  data wrangling and munging (e.g., files types, imputation, feature
# selection/engineering)
# 2. visualization
# ○ advanced matplotlib
# ○ libraries for DS and ML (e.g., Yellowbrick)
# ○ chart types and uses
# ○ effective communication
# 3. exploratory data analysis
# 4. imputing and missingness
# 5. linear algebra
# 6. data types: graph, spatiotemporal, image, text
# 7. ethics, security and privacy
#
# Late submission:
# The entire group, will receive zero credit for any project turned in after the time provided outside class for in class project. If you do not show up for
# the in-class project, you will receive a zero for that assignment.
#
# If homework is late it will be graded as normal and a 0.75 factor per day will be
# applied to that grade to yield the final, late grade. All homework submitted after one
# week of its due date receives a grade of zero.The assignments associated with your project throughout the semester are graded in the same way as homework, with the exception of the final product, which obviously cannot be done late
#
# Attendance:
# Mandatory.

# %% [markdown]
# AI Policy:
# 1. Work done solely by AI can be considered invalid. There has to be a blend of AI and self work for the assignments.
# 2. A proper citation should be provided: Name of the AI, version of the tool and date.
# 3. even if the code is AI assisted, one must be able to understand each line of the code and be explanatory. One must comment on each line which is AI generated and should be ready to modify or extend the code independently.
# 4. For visualization problems, customise and interpret results by yourself from AI generated code.. Should be able to explain any AI generated analysis.
# 5. IN group projects, ensure that each person is aware of the AI usage and maintain a collaborative learning within the team.
# 6. For writtten assignments, use AI for brainstorming and be ready to defend AI assisted content in the discussions or presentations.
# 7. Be mindful of the usage of AI so that it doesnt impact the learning outcome.

# %% [markdown]
# AI is a great way to leverage technology by making our work much simpler. Although it is a great tool, it must be used with caustion. I have worked with AI and have also used gpt api to customise and train the model with custom dataset. Sometimes, ai starts to halucinate or give wrong information. More importantly AI can make it more inefficient to think by ourselves.

# %% [markdown]
# Github link:
#
# https://github.com/vaishnavi-1328

# %% [markdown]
# Thinking clearly with data
# Chapter 1
#
# The chapter starts with the note of how much in abundance data and information is available since 2003 which must be analyzed and understood. An important task is to focus on the ideas and questions than technical details like mathematical formulas, statistics and questioning. Although the techniques is important to perform the data analysis, with the lack of understanding the context of the problem or how to approach it, the author says that it Is a complete disaster and can mislead the solution.
# The book can be read by even beginners to think clearly and approach problems easily for quantitative analysis.
#
# Cautionary Tales.
# Abe’s hasty diagnosis:
# Ethan
# Ethan had a son who was diagnosed as a sick child when he was underweight for his age after the family moved to Chicago. The doctors concluded that it is a celiac disease which the doctors were 80% accurate. Ethan wanted to look at the reports to confirm for himself.
# False negative rate= how many times sick person is healthy.
# False positive rate = how many times a healthy person is shown sick.
# Although Ethan did not have much knowledge on medicine, he was able to point out that the conclusion drawn was wrong and he was able to prove that the Abe’s has far lesser chances of having the disease.
#
# In other examples, the author has mode other references to show its significance.
#
# The author talks about how important it is to ask the right questions to think clearly.
# Although it is very important to think clearly, very little significance is given to it than technical concepts. There are 2 challenges that come with it:
# 1.	So much evidence is unreliable
# 2.	How to point out the opinions from experts who have been thinking clearly

# %% [markdown]
# ![Screenshot 2024-08-30 at 8.24.50 PM.png](attachment:5f83d0dc-44ef-4655-8dc2-b7bde2782693.png)

# %% [markdown]
# ![Screenshot 2024-08-30 at 8.25.58 PM.png](attachment:9ac6922d-31df-40b1-94f1-d2e99b5fad5d.png)

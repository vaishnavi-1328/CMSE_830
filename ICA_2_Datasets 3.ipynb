# %% [markdown]
# # Numbers and Datasets

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ____
#
# **Guidelines for ICAs**: Each student will turn in a notebook. Note that this is different from the first ICA. You will still work together, but you will come up with your own answers.
#
# Be sure to introduce yourself to all of your group members and tell them a bit about yourself.
#
# As you work, be sure to divide the effort evenly among your group members. It is strongly recommended that you read the notebook competely first so that you can intelligently divide the work, discuss the ideas and put results into your own notebook.
#
# The notebook is due at the end of class today - submit this notebook to D2L. Do not worry if you do not complete an ICA; sometimes we all get stuck on a "silly" coding issue. Just complete as much as you can and write out all of your ideas for the parts you don't get to (e.g., explain what you would have done if you had more time).
#
# Plan your time carefully!
#
# The problems get more "interesting" as you go, so be sure to move quickly through the early parts of this notebook. The "easy" parts come first and you don't want to spend all of your time there.
#
# **My name is:**
#
# *Members of my group:*
#
# * Vaishnavi S
# * Saraswati Baskaran
# * Derek
# * Alex
#
# **Markdown:** All text cells in Jupyter notebooks are written in markdown, which is a handy language that allows you to easily format your text. To see how I wrote this cell with markdown, just double-click on it. If you are not familiar with markdown, [here is a cheat sheet.](https://www.markdownguide.org/cheat-sheet/) Later, you will need to format equations in markdown, which will be done using [$\LaTeX$](https://notebook.community/TwistedHardware/mltutorial/notebooks/jupyter/2.%20Markdown%20&%20LaTeX).
#
# Whenever you see a "?", you should open a markodwn cell and put your answer.
#
# <div style="width: 100%; max-width: 100%; background-color: #f0f0f0; border: 2px solid #333; border-radius: 10px; padding: 20px; font-family: Arial, sans-serif; box-sizing: border-box;">
#   <h2 style="color: #2c3e50; text-align: center;">Using HTML in Jupyter Notebook Markdown Cells</h2>
#
#   <p style="color: #34495e; line-height: 1.6;">
#     I sometimes use HTML to format in these markdown cells; this gives you quite a bit more power if you like coding in HTML. Markdown, by design, is much simpler. Open this markdown cell to see the HTML code I used.
#   </p>
#
#   <div style="background-color: #6FC276; color: white; padding: 10px; margin-top: 20px; text-align: center; border-radius: 5px;">
#     <strong>Tip:</strong> HTML provides more formatting options than standard Markdown!
#   </div>
# </div>
# ____

# %% [markdown]
# ## Instructions
#
#
#
# This In-Class Assignment (ICA) is due at the end of class today.
#
# ✅ Put your name and all of the names of people you worked with today in the markdown cell at the top of this notebook.
#
# There are two goals of this assignment:
# 1. to be aware of the types of data in a given dataset
# 2. to become familar with a few, very common datasets
#
# ✅ You will work as a group. 🧑🏾‍💻  You will turn in your own assignment to D2L; however, your answers do not need to be the same as the answers of other members of your group. Work together, but feel free to try things on your own as well.
#
# ✅ Read through the next part of the notebook and follow the instructions. Run all of the code. If there is a problem, work with your group members or contact one of the instructors.

# %% [markdown]
# Many datasets are built into various Python libraries. You should know where you can find good datasets so they are readily available. You might also use these datasets in your projects. Or, you might just use them as part of your learning experience.
#
# We will explore two sources of data in Python: Seaborn and Scikit-Learn. As you will see, these two sources are quite different!
#
# Let's look at what is built into Seaborn. We will learn *a lot* more about Seaborn later in the course; for today, just run the code and understand what is there.

# %%
# bring Seaborn in

import seaborn as sns

# %%
# this is how you get the names of the Seaborn datasets

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# Read in a few datasets from Seaborn. Pay attention to this syntax and where the data is being stored.

# %%
# let's bring in a few datasets from Seaborn so that we can examine them
# --> feel free to examine others that might be interesting to your group

df_geyser= sns.load_dataset("geyser")
df_glue = sns.load_dataset("glue")
df_taxis = sns.load_dataset("taxis")
df_penguins= sns.load_dataset("penguins")
df_diamonds = sns.load_dataset("diamonds")

# %% [markdown]
# Many of these datasets are classics - you will encounter them many, many times. It's good to know they are built into Seaborn so that you don't need to find them, download them and read them in.

# %% [markdown]
# ___
# Getting data from Seaborn is pretty easy. We'll get back to these datasets below.
#
# Next, you are going to bring in datasets from `sklearn`. As you will see, the steps are quite different from Seaborn.

# %%
from sklearn import datasets
dir(datasets)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_arff_parser',
#  '_base',
#  '_california_housing',
#  '_covtype',
#  '_kddcup99',
#  '_lfw',
#  '_olivetti_faces',
#  '_openml',
#  '_rcv1',
#  '_samples_generator',
#  '_species_distributions',
#  '_svmlight_format_fast',
#  '_svmlight_format_io',
#  '_twenty_newsgroups',
#  'clear_data_home',
#  'dump_svmlight_file',
#  'fetch_20newsgroups',
#  'fetch_20newsgroups_vectorized',
#  'fetch_california_housing',
#  'fetch_covtype',
#  'fetch_kddcup99',
#  'fetch_lfw_pairs',
#  'fetch_lfw_people',
#  'fetch_olivetti_faces',
#  'fetch_openml',
#  'fetch_rcv1',
#  'fetch_species_distributions',
#  'get_data_home',
#  'load_breast_cancer',
#  'load_diabetes',
#  'load_digits',
#  'load_files',
#  'load_iris',
#  'load_linnerud',
#  'load_sample_image',
#  'load_sample_images',
#  'load_svmlight_file',
# ...

# %% [markdown]
# As you can see, there are many more datasets here. Most of these we will ignore for this class, because they are related to detailed issues in machine learning, but there are some nice datasets here that are not in Seaborn.
#
# Let's see how to load a dataset from `sklearn`. Note that what is imported is a container filled with lots of different types of information. It can look like a real mess! But, we can break out each item from the container.

# %%
datasets.load_digits()
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %% [markdown]
# What do you notice? You get a lot of output! This is because the `sklearn` datasets come with additional information. This can be super useful if you are not familiar with the dataset. But, you need to break things apart before you get started. Here is how you do that:

# %%
# actual data
# --> examine others that might be interesting to your group
digits_data = datasets.load_digits().data
wine_data = datasets.load_wine().data
# description of the data
digits_description = datasets.load_digits().DESCR
wine_description = datasets.load_wine().DESCR
# labels for the data
digits_labels = datasets.load_digits().target_names
wine_features = datasets.load_wine().feature_names

# %%
wine_features
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %% [markdown]
# ⏸ Pause for a moment and discuss within your group the differences between Seaborn and sklearn datasets. For example, what Python containers (e.g., list? tuple? dictionary?) do they naturally use? What would you do if you needed to convert from one container to another?
#
# ✅ Add some comments to the code below to show you know what it is doing. Add a markdown cell and describe this form of data.

# %%
#seaborn datasets focus more to explore visualization, statistics problems, and exploratory data analysis. The sklearn datasets intend more to build machine learning models. The type of containers that must be used can vary from one dataset to another hence it is not particular..

# %%
import matplotlib.pyplot as plt
plt.imshow(digits_data[80].reshape(8,8)) # #the imshow() is a function that prints the

# %% [markdown]
# We just read the Seaborn data into Pandas dataframes.
#
# We can view the dataframe by just putting the dataframe name into a cell and using shift-enter:

# %% [markdown]
# ____
# #### missing values
#
# We can also get quick statistics using `describe`. Pay attention to "count": what do you notice about this dataset?

# %%
df_glue.columns
# Out:
# Index(['Model', 'Year', 'Encoder', 'Task', 'Score'], dtype='object')

# %%
df_glue.head()
# Out:
#          Model  Year      Encoder  Task  Score
# 0        ERNIE  2019  Transformer  CoLA   75.5
# 1           T5  2019  Transformer  CoLA   71.6
# 2      RoBERTa  2019  Transformer  CoLA   67.8
# 3         BERT  2018  Transformer  CoLA   60.5
# 4  BiLSTM+ELMo  2018         LSTM  CoLA   32.1

# %%
df_diamonds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
import numpy as np
df_glue_subset = df_glue[['Year','Score']]

# create a boolean mask: True for NaN, False for finite values
nan_mask = df_glue_subset.isna()

# convert boolean mask to integer (False becomes 0, True becomes 1)
nan_array = nan_mask.astype(int).to_numpy()

# size the plot
plt.figure(figsize=(12, 6))

# imshow with interpolation set to 'nearest' and aspect to 'auto'
im = plt.imshow(nan_array.T, interpolation='nearest', aspect='auto', cmap='viridis')

plt.xlabel('glue Index')
plt.ylabel('Features')
plt.title('Visualizing Missing Values in a Dataset')

# y-axis tick labels to feature names
plt.yticks(range(len(df_glue_subset.columns)), df_glue_subset.columns)

# x-axis ticks
num_glue = nan_array.shape[0]
plt.xticks(np.linspace(0, num_glue-1, min(10, num_glue)).astype(int))

plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# %%
df_diamonds_subset.isna().any(axis=1).sum()
# Out:
# 0

# %%
df_diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# ✅ Pick 4 Seaborn datasets and answer these questions for all 4:
# * how many columns are there in that dataset?
# * for diamonds: 10, penguins: 7, taxis: 14, glue: 5
# * what is in each column? that is: real? ordinal? category? nominal? Diamonds: nominal and real values, penguins: Nonimal and real values. Taxis: nominal and real columns , glue: nomial and real
# * in the first line from `describe`, you have the count - for each of the three datasets you picked, is the count the same for each column? if not, why not? for diamonds, yes, penguin: yes, taxis: yes, glue: yes
# * do you see any NaNs in any of your datasets? Diamonds: No, Penguin dataset: yes, Taxis: yes, glue: yes
# * when you use `describe`, what does Pandas do with columns for which the mean and std don't make any sense? the columns where there are non-numeric columns, Pandas omits those columns. The penguin dataset contains nominal columns columns but the describe function did not give information on the mean and the std.

# %% [markdown]
# ✅ Within your group, discuss what _message_ each of these datasets has. That is, just by looking at the data, what can you infer about what it might be able to tell you? Summarize that message for three datasets:
#
# 1. message for penguins is: A majority of the penguins is from Biscoe and from Dream, the data is skewed.
# 2. message from diamonds: The price for the diamonds can go from the range 53940 to 18823. The sizes of the diamonds do not vary much because the std of x,y,z is close to 1 where the maximum value is 10,59 and 32 respectively.
# 3. message for the taxis: The dataset can be used to meansure the efficiency of the taxis. It has the information of the rides, the fares, id, number of trip, etc which gives a lot of information which can be used to understand the pattern of the trips.
# 4. The dataset talks about the different models of LLM's, which year it was released, most of which were between 2017 to 2019 and what the score is for each model.

# %% [markdown]
# ✅ Next, visualize your datasets. Choose 4 of your favorite Seaborn datasets and use `pairplot` to explore your data. Go to this [website](https://seaborn.pydata.org/generated/seaborn.pairplot.html) and see what the options are. Try several options.
#
# ✅ Answer these questions after each plot:
# * what do you see along the diagonal? The features gets plotted against itself, so there is not much that we can infer against the diagonal panels.
# * what do you see in the off-diagonal panels? in the of-diagonal panels, we see that each of the feature gets plotted against the other features. The diamonds dataset gives the information that there is a huge variation in the price against the changes in the depth, x,y and z. The penguin dataset: The body mass is positively correlated with flipper_length. certain species can be easily identified using the bill lenght and depth.
# * for each dataset, do you see a clearer message appearing? what is that message?

# %%
# here is an example for the penguin dataset
sns.pairplot(df_diamonds, hue= 'carat')

# %%
sns.pairplot(df_penguins)

# %%
sns.pairplot(df_taxis)

# %%
sns.pairplot(df_glue)

# %% [markdown]
# _____
#
# 👍🏻
#
# Congrats! You have reached the end.
#
# Don't forget to put your name at the top, and the names of the people you worked with.
#
# Upload the notebook into D2L.
